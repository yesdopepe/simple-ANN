# %% [markdown]
# <a href="https://www.kaggle.com/code/yesdodata/breast-cancer-type-prediction-using-a-basic-ann?scriptVersionId=176896623" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
df = pd.read_csv("/kaggle/input/cancer-dataset/wdbc.csv")

# %%
df

# %%
X = df.iloc[:,2:]
Y = df.iloc[:,1]

# %%
Y

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
Y = encoder.fit_transform(Y)

# %%
Y

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
X

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation,Input

model = Sequential()
model.add(Dense(128, activation='sigmoid', input_shape=(30,)))
model.add(Dense(32, activation="sigmoid"))
model.add(Dense(1, activation="sigmoid"))

# %%
model.summary()
# Out:
# Model: "sequential_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_18 (Dense)                │ (None, 128)            │         3,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,129 (31.75 KB)
#  Trainable params: 8,129 (31.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss="binary_crossentropy",
              optimizer="adam",
              metrics = ['accuracy'])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %%
model.fit(X_train, Y_train, batch_size=256, epochs=100)
# Out:
# Epoch 1/100
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5898 - loss: 0.6887
# W0000 00:00:1715370425.334370     104 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 422ms/step - accuracy: 0.6136 - loss: 0.6754
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6241 - loss: 0.6448
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6241 - loss: 0.6211
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6136 - loss: 0.6018
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6312 - loss: 0.5752
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6687 - loss: 0.5490
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7250 - loss: 0.5286
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7739 - loss: 0.5020
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8081 - loss: 0.4853
# Epoch 10/100
# ...

# %%
pred = model.predict(X_test)
pred
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# array([[0.12974171],
#        [0.00793703],
#        [0.9920161 ],
#        [0.00339627],
#        [0.00680792],
#        [0.11389382],
#        [0.9799479 ],
#        [0.7063981 ],
#        [0.00464681],
#        [0.9867333 ],
#        [0.52600956],
#        [0.00408417],
#        [0.04430903],
#        [0.01277843],
#        [0.00730114],
#        [0.01888524],
#        [0.9938553 ],
#        [0.99408025],
#        [0.9778149 ],
#        [0.00824415],
#        [0.85597223],
#        [0.00464655],
#        [0.01484296],
#        [0.00549278],
#        [0.00727844],
#        [0.9928213 ],
#        [0.0036125 ],
#        [0.9944311 ],
#        [0.01291693],
#        [0.9948382 ],
#        [0.42634377],
#        [0.98996   ],
#        [0.00510427],
#        [0.02581675],
#        [0.00672598],
#        [0.99377066],
#        [0.00753316],
#        [0.99418795],
#        [0.00876056],
#        [0.0069876 ],
#        [0.01228075],
# ...

# %%
pred = pred.round()
from sklearn.metrics import classification_report,confusion_matrix

print(classification_report(Y_test, pred))
print(confusion_matrix(Y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        73
#            1       1.00      0.98      0.99        41
#
#     accuracy                           0.99       114
#    macro avg       0.99      0.99      0.99       114
# weighted avg       0.99      0.99      0.99       114
#
# [[73  0]
#  [ 1 40]]
